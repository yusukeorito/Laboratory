# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from itertools import cycle

plt.style.use("ggplot")
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %%
data = np.loadtxt('../output/Energy_C1_L40_T5.00_2026.dat')

# %%
def calc_mse(data:ndarray):
    linear_reg = np.polyfit(data[1:,1], data[1:,0], 1)
    func = np.poly1d(linear_reg)
    y_true = data[1:,0]
    y_pred = func(data[1:,1])
    mse = mean_squared_error(y_true, y_pred)
    return mse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nm/f1mftswx2bn4x3l5cmqskq5r0000gn/T/ipykernel_17415/1406695508.py in <module>
# ----> 1 def calc_mse(data:ndarray):
#       2     linear_reg = np.polyfit(data[1:,1], data[1:,0], 1)
#       3     func = np.poly1d(linear_reg)
#       4     y_true = data[1:,0]
#       5     y_pred = func(data[1:,1])
#
# NameError: name 'ndarray' is not defined

# %%
fig, ax = plt.subplots(figsize=(8,6))
l1, l2= "samples", "self_learning_fit"
sns.scatterplot(data[1:,1],data[1:,0],color='red', ax=ax, label=l1)
ax.plot(data[1:,1],y_pred,lw=4, color='black', label=l2)
#ax.set_xlabel("C1/N", fontsize=16)
#ax.set_ylabel("E/N", fontsize=16)
ax.legend(fontsize=25)
#ax.grid()
plt.tight_layout()
plt.show()
# Out:
# /Users/oritoyusuke/miniforge3/envs/python38/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
linear_reg = np.polyfit(data[1:,1], data[1:,0], 1)
func = np.poly1d(linear_reg)

# %%
print('[傾き,切片]=', linear_reg)
# Out:
# [傾き,切片]= [-1.07092165  0.00656021]

# %%
from sklearn.metrics import mean_absolute_error
y_true = data[1:,0]
y_pred = func(data[1:,1])

# %%
print('平均二乗誤差:',mean_absolute_error(y_true, y_pred))
# Out:
# 平均二乗誤差: 0.0036090826958369215

# %%
data_ = np.loadtxt('../output/J2_0.5_Energy_C1_L40_T5.00_2026.dat')

# %%
fig, ax = plt.subplots(figsize=(8,6))
l1, l2= "samples", "self_learning_fit"
sns.scatterplot(data_[1:,1],data_[1:,0],color='green', ax=ax, label=l1)
#ax.plot(data[1:,1],y2,lw=4, color='black', label=l2)
ax.set_xlabel("C1/N", fontsize=16)
ax.set_ylabel("E/N", fontsize=16)
ax.legend()
ax.grid()
plt.tight_layout()
plt.show()
# Out:
# /Users/oritoyusuke/miniforge3/envs/python38/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
linear_reg_ = np.polyfit(data_[1:,1], data_[1:,0], 1)
func_ = np.poly1d(linear_reg_)
print('[傾き,切片]=', linear_reg_)
# Out:
# [傾き,切片]= [-1.18752996 -0.00306038]

# %%
y_true_ = data_[1:,0]
y_pred_ = func(data_[1:,1])
print('平均二乗誤差:',mean_absolute_error(y_true_, y_pred_))
# Out:
# 平均二乗誤差: 0.07107298035278282

# %%
data_ = np.loadtxt('../output/anti_Energy_C1_L40_T5.00_2026.dat')

# %%
fig, ax = plt.subplots(figsize=(8,6))
l1, l2= "samples", "self_learning_fit"
sns.scatterplot(data_[1:,1],data_[1:,0],color='green', ax=ax, label=l1)
#ax.plot(data[1:,1],y2,lw=4, color='black', label=l2)
ax.set_xlabel("C1/N", fontsize=16)
ax.set_ylabel("E/N", fontsize=16)
ax.legend()
ax.grid()
plt.tight_layout()
plt.show()
# Out:
# /Users/oritoyusuke/miniforge3/envs/python38/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np

# %%
print(np.exp(-0.4016064257028112*0.2665951619080564))
# Out:
# 0.8984660756839072

# %%
np.sqrt( 0.07107298035278282)
# Out:
# 0.26659516190805643

# %%
1/2.49
# Out:
# 0.4016064257028112
