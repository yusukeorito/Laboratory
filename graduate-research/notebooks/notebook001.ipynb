# %% [markdown]
# ## エネルギーと磁化の挙動確認

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sns

# %%
data = np.loadtxt('../output/Energy_Magnetization_L10_2026.dat')
data2 = np.loadtxt('../output/Energy_Magnetization_L10_T5.000000_2026.dat')

# %%
energy = data[:,0]
mag = data[:,1]
mag2 = data2[:,1]

# %%
plt.plot(mag[:1000])

# %%
plt.plot(mag2[:1000])
